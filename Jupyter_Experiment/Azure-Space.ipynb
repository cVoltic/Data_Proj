# %%
"""
    #Start by loading a workspace from configuration file
    #Import azure core package
"""
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.0.85 to work with ml-fullpipe-practice

# %%
"""
    #Prepare data by first uploading it to the cloud blob storage
"""
from azureml.core import Dataset

#Pre-transformation step: turn xlsx to .csv
import pandas as pd
pre_df = pd.read_excel("./data/shuttles.xlsx")
pre_df.to_csv("./data/shuttles.csv", sep=",")

#Begin uploading data to Azure Blob Storage
default_ds = ws.get_default_datastore()
default_ds.upload_files(files=['./data/companies.csv', './data/reviews.csv', './data/shuttles.csv'], # Upload the diabetes csv files in /data
                       target_path='space-data/', # Put it in a folder path in the datastore
                       overwrite=True, # Replace existing files of the same name
                       show_progress=True)

#Create a tabular dataset from the path on the datastore (this may take a short while)
companies_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'space-data/companies.csv'))
reviews_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'space-data/reviews.csv'))
shuttles_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'space-data/shuttles.csv'))

# Register the tabular dataset
# Data Extraction Step (Essentially)
companies_data_set = companies_data_set.register(workspace=ws, 
                           name='space companies dataset',
                           description='companies data',
                           tags = {'format':'CSV'},
                           create_new_version=True)
reviews_data_set = reviews_data_set.register(workspace=ws, 
                           name='space reviews dataset',
                           description='companies data',
                           tags = {'format':'CSV'},
                           create_new_version=True)
shuttles_data_set = shuttles_data_set.register(workspace=ws, 
                           name='space shuttles dataset',
                           description='shuttles data',
                           tags = {'format':'CSV'},
                           create_new_version=True)

print('Dataset ready.')
# Out:
# Uploading an estimated of 3 files
# Uploading ./data/companies.csv
# Uploading ./data/reviews.csv
# Uploading ./data/shuttles.csv
# Uploaded ./data/companies.csv, 1 files out of an estimated total of 3
# Uploaded ./data/reviews.csv, 2 files out of an estimated total of 3
# Uploaded ./data/shuttles.csv, 3 files out of an estimated total of 3
# Uploaded 3 files
# Dataset ready.

# %%
#companies_data_set.to_pandas_dataframe()
#shuttles_data_set.to_pandas_dataframe()

# %%
#Create a Folder to Store Pipeline Works
import os
# Create a folder for the pipeline step files
experiment_folder = 'space_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# space_pipeline

# %%
#Data Transformation Step
import pandas as pd

#Define function to transform our data.
def _is_true(x):
    return x == "t"


def _parse_percentage(x):
    if (x != ""):
        return float(x.replace("%", ""))/100.
    else:
        return 0.0


def _parse_money(x):
    return float(x.replace("$", "").replace(",", ""))


def preprocess_companies(companies: pd.DataFrame) -> pd.DataFrame:
    """Preprocess the data for companies.

        Args:
            companies: Source data.
        Returns:
            Preprocessed data.

    """

    companies["iata_approved"] = companies["iata_approved"].apply(_is_true)

    companies["company_rating"] = companies["company_rating"].apply(_parse_percentage)

    return companies


def preprocess_shuttles(shuttles: pd.DataFrame) -> pd.DataFrame:
    """Preprocess the data for shuttles.

        Args:
            shuttles: Source data.
        Returns:
            Preprocessed data.

    """
    shuttles["d_check_complete"] = shuttles["d_check_complete"].apply(_is_true)

    shuttles["moon_clearance_complete"] = shuttles["moon_clearance_complete"].apply(
        _is_true
    )

    shuttles["price"] = shuttles["price"].apply(_parse_money)

    return shuttles

# %%
#Run Preprocess step to cleanup data
preprocessed_companies_data_set = preprocess_companies(companies_data_set.to_pandas_dataframe())
preprocessed_shuttles_data_set = preprocess_shuttles(shuttles_data_set.to_pandas_dataframe())
preprocessed_reviews_data_set = reviews_data_set.to_pandas_dataframe()
# Out:
# "\npreprocessed_companies_data_set = companies_data_set.register(workspace=ws, \n                           name='space companies dataset',\n                           description='companies data',\n                           tags = {'format':'Pandas-DataFrame'},\n                           create_new_version=True)\n\npreprocessed_shuttles_data_set = shuttles_data_set.register(workspace=ws, \n                           name='space shuttles dataset',\n                           description='shuttles data',\n                           tags = {'format':'Pandas-DataFrame'},\n                           create_new_version=True)\n"

# %%
#More DataEngineer Step
#Create Master Table
def create_master_table(
    shuttles: pd.DataFrame, companies: pd.DataFrame, reviews: pd.DataFrame
) -> pd.DataFrame:
    """Combines all data to create a master table.

        Args:
            shuttles: Preprocessed data for shuttles.
            companies: Preprocessed data for companies.
            reviews: Source data for reviews.
        Returns:
            Master table.

    """
    rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")

    with_companies = rated_shuttles.merge(
        companies, left_on="company_id", right_on="id"
    )

    master_table = with_companies.drop(["shuttle_id", "company_id"], axis=1)
    master_table = master_table.dropna()
    return master_table

# %%
#Create Master Table and Store it in the blob storage
master_table = create_master_table(preprocessed_shuttles_data_set, preprocessed_companies_data_set, preprocessed_reviews_data_set)
master_table.to_csv("./data/space_master.csv", sep=",")


#Upload it to blob storage
default_ds.upload_files(files=['./data/space_master.csv'], # Upload the diabetes csv files in /data
                       target_path='space-data/', # Put it in a folder path in the datastore
                       overwrite=True, # Replace existing files of the same name
                       show_progress=True)

#Get Master Data Table
master_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'space-data/space_master.csv'))

# Register the tabular dataset for future usage
master_data_set = master_data_set.register(workspace=ws, 
                           name='space master dataset',
                           description='master data',
                           tags = {'format':'CSV'},
                           create_new_version=True)
# Out:
# Uploading an estimated of 1 files
# Uploading ./data/space_master.csv
# Uploaded ./data/space_master.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
#          Column1   id_x           shuttle_location shuttle_type engine_type  \
# 0              0  63561                       Niue      Type V5     Quantum
# 1              0  63561                       Niue      Type V5     Quantum
# 2              0  63561                       Niue      Type V5     Quantum
# 3              0  63561                       Niue      Type V5     Quantum
# 4           1353  53260                       Niue      Type V5     Quantum
# 5           1353  53260                       Niue      Type V5     Quantum
# 6           1353  53260                       Niue      Type V5     Quantum
# 7           1353  53260                       Niue      Type V5     Quantum
# 8           1984  51019                       Niue      Type V5     Quantum
# 9           1984  51019                       Niue      Type V5     Quantum
# 10          1984  51019                       Niue      Type V5     Quantum
# 11          1984  51019                       Niue      Type V5     Quantum
# 12          4878  53898                       Niue      Type V5      Plasma
# 13          4878  53898                       Niue      Type V5      Plasma
# 14          4878  53898                       Niue      Type V5      Plasma
# 15          4878  53898                       Niue      Type V5      Plasma
# 16             1  36260                   Anguilla      Type V5     Quantum
# 17             1  36260                   Anguilla      Type V5     Quantum
# 18             1  36260                   Anguilla      Type V5     Quantum
# 19             1  36260                   Anguilla      Type V5     Quantum
# 20             1  36260                   Anguilla      Type V5     Quantum
# 21             1  36260                   Anguilla      Type V5     Quantum
# 28         16447  32973                   Anguilla      Type O3     Quantum
# 29         16447  32973                   Anguilla      Type O3     Quantum
# 30         16447  32973                   Anguilla      Type O3     Quantum
# 31         16447  32973                   Anguilla      Type O3     Quantum
# 32         16447  32973                   Anguilla      Type O3     Quantum
# 33         16447  32973                   Anguilla      Type O3     Quantum
# 34         16448   5333                   Anguilla      Type O3     Quantum
# 35         16448   5333                   Anguilla      Type O3     Quantum
# ...          ...    ...                        ...          ...         ...
# 1853656    75370  23604         Russian Federation      Type V5      Plasma
# 1853673    75414  29334      Sao Tome and Principe      Type V7     Quantum
# 1853674    75414  29334      Sao Tome and Principe      Type V7     Quantum
# 1853697    75435  37966         Russian Federation      Type V7      Plasma
# 1853708    75452  65762                   Barbados      Type V5      Plasma
# 1853733    75495  13982                   Barbados      Type V5     Quantum
# 1853734    75495  13982                   Barbados      Type V5     Quantum
# 1863945    75508  49839                     Rwanda      Type V5     Nuclear
# 1863946    75508  49839                     Rwanda      Type V5     Nuclear
# 1863947    75508  49839                     Rwanda      Type V5     Nuclear
# 1863989    75585  60526                   Anguilla      Type V5     Quantum
# 1863998    75605  62216                       Chad      Type F5     Quantum
# 1864074    75792  23617                 Uzbekistan      Type V5      Plasma
# 1864086    75819  59219                Switzerland      Type V5      Plasma
# 1864094    75830  17084                 Costa Rica      Type V5     Quantum
# 1864281    75869  62754                 Costa Rica      Type I5      Plasma
# 1864306    75913  39094         Russian Federation      Type F5     Quantum
# 1864307    75913  39094         Russian Federation      Type F5     Quantum
# 1864315    75922  22687                     Rwanda      Type V5      Plasma
# 1864316    75922  22687                     Rwanda      Type V5      Plasma
# 1864357    75985  20330                 Uzbekistan      Type V5     Quantum
# 1864386    76033  16445                  Nicaragua      Type V5      Plasma
# 1864448    76124  76469  Bouvet Island (Bouvetoya)      Type V5     Quantum
# 1864517    76207  31982                     Rwanda      Type G0      Plasma
# 1864518    76207  31982                     Rwanda      Type G0      Plasma
# 1864519    76207  31982                     Rwanda      Type G0      Plasma
# 1864576    76284  48202                 Micronesia      Type V5      Plasma
# 1864577    76284  48202                 Micronesia      Type V5      Plasma
# 1864695    76452  14586                     Gambia      Type F5     Quantum
# 1864889    76783  75780         Russian Federation      Type V5      Plasma
#
#                     engine_vendor  engines  passenger_capacity  \
# 0              ThetaBase Services      1.0                   2
# 1              ThetaBase Services      1.0                   2
# 2              ThetaBase Services      1.0                   2
# 3              ThetaBase Services      1.0                   2
# 4        Banks, Wood and Phillips      1.0                   2
# 5        Banks, Wood and Phillips      1.0                   2
# 6        Banks, Wood and Phillips      1.0                   2
# 7        Banks, Wood and Phillips      1.0                   2
# 8              ThetaBase Services      1.0                   2
# 9              ThetaBase Services      1.0                   2
# 10             ThetaBase Services      1.0                   2
# 11             ThetaBase Services      1.0                   2
# 12             ThetaBase Services      3.0                   5
# 13             ThetaBase Services      3.0                   5
# 14             ThetaBase Services      3.0                   5
# 15             ThetaBase Services      3.0                   5
# 16             ThetaBase Services      1.0                   2
# 17             ThetaBase Services      1.0                   2
# 18             ThetaBase Services      1.0                   2
# 19             ThetaBase Services      1.0                   2
# 20             ThetaBase Services      1.0                   2
# 21             ThetaBase Services      1.0                   2
# 28             ThetaBase Services      1.0                   3
# 29             ThetaBase Services      1.0                   3
# 30             ThetaBase Services      1.0                   3
# 31             ThetaBase Services      1.0                   3
# 32             ThetaBase Services      1.0                   3
# 33             ThetaBase Services      1.0                   3
# 34             ThetaBase Services      1.0                   2
# 35             ThetaBase Services      1.0                   2
# ...                           ...      ...                 ...
# 1853656        ThetaBase Services      1.0                   2
# 1853673        ThetaBase Services      1.0                   3
# 1853674        ThetaBase Services      1.0                   3
# 1853697        ThetaBase Services      0.0                   2
# 1853708        ThetaBase Services      1.0                   5
# 1853733        ThetaBase Services      0.0                   2
# 1853734        ThetaBase Services      0.0                   2
# 1863945  Banks, Wood and Phillips      1.0                   1
# 1863946  Banks, Wood and Phillips      1.0                   1
# 1863947  Banks, Wood and Phillips      1.0                   1
# 1863989        ThetaBase Services      1.0                   2
# 1863998        ThetaBase Services      1.0                   2
# 1864074        ThetaBase Services      2.0                   4
# 1864086        ThetaBase Services      2.0                   6
# 1864094        ThetaBase Services      1.0                   2
# 1864281        ThetaBase Services      0.0                   1
# 1864306        ThetaBase Services      1.0                   2
# 1864307        ThetaBase Services      1.0                   2
# 1864315        ThetaBase Services      0.0                   2
# 1864316        ThetaBase Services      0.0                   2
# 1864357        ThetaBase Services      1.0                   2
# 1864386        ThetaBase Services      1.0                   1
# 1864448        ThetaBase Services      1.0                   2
# 1864517        ThetaBase Services      1.0                   4
# 1864518        ThetaBase Services      1.0                   4
# 1864519        ThetaBase Services      1.0                   4
# 1864576        ThetaBase Services      0.0                   2
# 1864577        ThetaBase Services      0.0                   2
# 1864695        ThetaBase Services      1.0                   1
# 1864889        ThetaBase Services      1.0                   2
#
#         cancellation_policy  crew      ...        review_scores_crew  \
# 0                    strict   1.0      ...                      10.0
# 1                    strict   1.0      ...                      10.0
# 2                    strict   1.0      ...                      10.0
# 3                    strict   1.0      ...                      10.0
# 4                    strict   1.0      ...                      10.0
# 5                    strict   1.0      ...                      10.0
# 6                    strict   1.0      ...                      10.0
# 7                    strict   1.0      ...                      10.0
# 8                  flexible   1.0      ...                      10.0
# 9                  flexible   1.0      ...                      10.0
# 10                 flexible   1.0      ...                      10.0
# 11                 flexible   1.0      ...                      10.0
# 12                   strict   3.0      ...                      10.0
# 13                   strict   3.0      ...                      10.0
# 14                   strict   3.0      ...                      10.0
# 15                   strict   3.0      ...                      10.0
# 16                   strict   1.0      ...                       9.0
# 17                   strict   1.0      ...                       9.0
# 18                   strict   1.0      ...                       9.0
# 19                   strict   1.0      ...                       9.0
# 20                   strict   1.0      ...                       9.0
# 21                   strict   1.0      ...                       9.0
# 28                   strict   3.0      ...                      10.0
# 29                   strict   3.0      ...                      10.0
# 30                   strict   3.0      ...                      10.0
# 31                   strict   3.0      ...                      10.0
# 32                   strict   3.0      ...                      10.0
# 33                   strict   3.0      ...                      10.0
# 34                   strict   1.0      ...                      10.0
# 35                   strict   1.0      ...                      10.0
# ...                     ...   ...      ...                       ...
# 1853656            moderate   1.0      ...                      10.0
# 1853673            flexible   1.0      ...                      10.0
# 1853674            flexible   1.0      ...                      10.0
# 1853697            flexible   1.0      ...                      10.0
# 1853708            moderate   4.0      ...                      10.0
# 1853733              strict   1.0      ...                      10.0
# 1853734              strict   1.0      ...                      10.0
# 1863945            flexible   1.0      ...                      10.0
# 1863946            flexible   1.0      ...                      10.0
# 1863947            flexible   1.0      ...                      10.0
# 1863989            flexible   1.0      ...                       8.0
# 1863998            moderate   1.0      ...                      10.0
# 1864074              strict   2.0      ...                      10.0
# 1864086              strict   3.0      ...                      10.0
# 1864094            flexible   1.0      ...                      10.0
# 1864281            flexible   1.0      ...                      10.0
# 1864306              strict   1.0      ...                      10.0
# 1864307              strict   1.0      ...                      10.0
# 1864315            flexible   1.0      ...                       6.0
# 1864316            flexible   1.0      ...                       6.0
# 1864357            flexible   1.0      ...                      10.0
# 1864386            flexible   3.0      ...                      10.0
# 1864448            moderate   1.0      ...                      10.0
# 1864517              strict   3.0      ...                      10.0
# 1864518              strict   3.0      ...                      10.0
# 1864519              strict   3.0      ...                      10.0
# 1864576            flexible   1.0      ...                      10.0
# 1864577            flexible   1.0      ...                      10.0
# 1864695            flexible   1.0      ...                       8.0
# 1864889              strict   1.0      ...                      10.0
#
#          review_scores_location  review_scores_price  number_of_reviews  \
# 0                           9.0                 10.0                133
# 1                           9.0                 10.0                133
# 2                           9.0                 10.0                133
# 3                           9.0                 10.0                133
# 4                           9.0                 10.0                 37
# 5                           9.0                 10.0                 37
# 6                           9.0                 10.0                 37
# 7                           9.0                 10.0                 37
# 8                           9.0                  9.0                 10
# 9                           9.0                  9.0                 10
# 10                          9.0                  9.0                 10
# 11                          9.0                  9.0                 10
# 12                          9.0                 10.0                 11
# 13                          9.0                 10.0                 11
# 14                          9.0                 10.0                 11
# 15                          9.0                 10.0                 11
# 16                          9.0                  9.0                  3
# 17                          9.0                  9.0                  3
# 18                          9.0                  9.0                  3
# 19                          9.0                  9.0                  3
# 20                          9.0                  9.0                  3
# 21                          9.0                  9.0                  3
# 28                         10.0                  8.0                  1
# 29                         10.0                  8.0                  1
# 30                         10.0                  8.0                  1
# 31                         10.0                  8.0                  1
# 32                         10.0                  8.0                  1
# 33                         10.0                  8.0                  1
# 34                          8.0                  6.0                  1
# 35                          8.0                  6.0                  1
# ...                         ...                  ...                ...
# 1853656                    10.0                 10.0                  1
# 1853673                     8.0                 10.0                  2
# 1853674                     8.0                 10.0                  2
# 1853697                    10.0                 10.0                  1
# 1853708                     8.0                  8.0                  1
# 1853733                    10.0                 10.0                  1
# 1853734                    10.0                 10.0                  1
# 1863945                    10.0                 10.0                  2
# 1863946                    10.0                 10.0                  2
# 1863947                    10.0                 10.0                  2
# 1863989                     8.0                  8.0                  1
# 1863998                    10.0                 10.0                  1
# 1864074                    10.0                 10.0                  1
# 1864086                     8.0                 10.0                  1
# 1864094                     9.0                 10.0                  2
# 1864281                    10.0                 10.0                  2
# 1864306                    10.0                 10.0                  1
# 1864307                    10.0                 10.0                  1
# 1864315                     2.0                  2.0                  2
# 1864316                     2.0                  2.0                  2
# 1864357                    10.0                 10.0                  1
# 1864386                    10.0                 10.0                  3
# 1864448                    10.0                 10.0                  1
# 1864517                    10.0                 10.0                  2
# 1864518                    10.0                 10.0                  2
# 1864519                    10.0                 10.0                  2
# 1864576                    10.0                 10.0                  1
# 1864577                    10.0                 10.0                  1
# 1864695                    10.0                  8.0                  2
# 1864889                    10.0                 10.0                  1
#
#          reviews_per_month   id_y  company_rating          company_location  \
# 0                     1.65  35029            1.00                      Niue
# 1                     1.65  35029            1.00                      Niue
# 2                     1.65  35029            1.00                      Niue
# 3                     1.65  35029            1.00                      Niue
# 4                     0.48  35029            1.00                      Niue
# 5                     0.48  35029            1.00                      Niue
# 6                     0.48  35029            1.00                      Niue
# 7                     0.48  35029            1.00                      Niue
# 8                     0.15  35029            1.00                      Niue
# 9                     0.15  35029            1.00                      Niue
# 10                    0.15  35029            1.00                      Niue
# 11                    0.15  35029            1.00                      Niue
# 12                    0.21  35029            1.00                      Niue
# 13                    0.21  35029            1.00                      Niue
# 14                    0.21  35029            1.00                      Niue
# 15                    0.21  35029            1.00                      Niue
# 16                    0.09  30292            0.67                  Anguilla
# 17                    0.09  30292            0.67                  Anguilla
# 18                    0.09  30292            0.67                  Anguilla
# 19                    0.09  30292            0.67                  Anguilla
# 20                    0.09  30292            0.67                  Anguilla
# 21                    0.09  30292            0.67                  Anguilla
# 28                    0.21  30292            0.67                  Anguilla
# 29                    0.21  30292            0.67                  Anguilla
# 30                    0.21  30292            0.67                  Anguilla
# 31                    0.21  30292            0.67                  Anguilla
# 32                    0.21  30292            0.67                  Anguilla
# 33                    0.21  30292            0.67                  Anguilla
# 34                    0.03  30292            0.67                  Anguilla
# 35                    0.03  30292            0.67                  Anguilla
# ...                    ...    ...             ...                       ...
# 1853656               1.00  36476            1.00              Saint Helena
# 1853673               2.00  46943            0.94                      Peru
# 1853674               2.00  46943            0.94                      Peru
# 1853697               1.00  32817            1.00        Russian Federation
# 1853708               1.00   3199            1.00
# 1853733               1.00  43799            1.00                 Nicaragua
# 1853734               1.00  43799            1.00                 Nicaragua
# 1863945               2.00   2878            0.93    Bosnia and Herzegovina
# 1863946               2.00   2878            0.93    Bosnia and Herzegovina
# 1863947               2.00   2878            0.93    Bosnia and Herzegovina
# 1863989               1.00  16031            1.00
# 1863998               1.00  31216            1.00                      Togo
# 1864074               1.00  32684            0.00                  Kiribati
# 1864086               1.00  41251            0.00  Turks and Caicos Islands
# 1864094               2.00   2870            0.00
# 1864281               2.00  21127            0.00                   Moldova
# 1864306               1.00  42904            0.70        Russian Federation
# 1864307               1.00  42904            0.70        Russian Federation
# 1864315               2.00  15532            0.00                   Estonia
# 1864316               2.00  15532            0.00                   Estonia
# 1864357               1.00   5701            1.00                Costa Rica
# 1864386               3.00  13728            1.00                  Pakistan
# 1864448               1.00  41714            1.00                   Lebanon
# 1864517               2.00  33788            0.00                 Venezuela
# 1864518               2.00  33788            0.00                 Venezuela
# 1864519               2.00  33788            0.00                 Venezuela
# 1864576               1.00  14296            0.00               Netherlands
# 1864577               1.00  14296            0.00               Netherlands
# 1864695               2.00   4873            0.00                    France
# 1864889               1.00  47766            1.00                Uzbekistan
#
#          total_fleet_count  iata_approved
# 0                      4.0          False
# 1                      4.0          False
# 2                      4.0          False
# 3                      4.0          False
# 4                      4.0          False
# 5                      4.0          False
# 6                      4.0          False
# 7                      4.0          False
# 8                      4.0          False
# 9                      4.0          False
# 10                     4.0          False
# 11                     4.0          False
# 12                     4.0          False
# 13                     4.0          False
# 14                     4.0          False
# 15                     4.0          False
# 16                     6.0          False
# 17                     6.0          False
# 18                     6.0          False
# 19                     6.0          False
# 20                     6.0          False
# 21                     6.0          False
# 28                     6.0          False
# 29                     6.0          False
# 30                     6.0          False
# 31                     6.0          False
# 32                     6.0          False
# 33                     6.0          False
# 34                     6.0          False
# 35                     6.0          False
# ...                    ...            ...
# 1853656                1.0          False
# 1853673                2.0          False
# 1853674                2.0          False
# 1853697                1.0          False
# 1853708                1.0          False
# 1853733                2.0          False
# 1853734                2.0          False
# 1863945                3.0          False
# 1863946                3.0          False
# 1863947                3.0          False
# 1863989                1.0          False
# 1863998                1.0          False
# 1864074                1.0          False
# 1864086                1.0          False
# 1864094                1.0          False
# 1864281                5.0          False
# 1864306                2.0          False
# 1864307                2.0          False
# 1864315                2.0          False
# 1864316                2.0          False
# 1864357                1.0          False
# 1864386                1.0          False
# 1864448                1.0          False
# 1864517                3.0          False
# 1864518                3.0          False
# 1864519                3.0          False
# 1864576                4.0          False
# 1864577                4.0          False
# 1864695                1.0          False
# 1864889                1.0          False
#
# [831220 rows x 27 columns]

# %%
#Rerturn all versions of given dataset
print("Datasets:")
for dataset_name in list(ws.datasets.keys()):
    dataset = Dataset.get_by_name(ws, dataset_name)
    print("\t", dataset.name, 'version', dataset.version)
# Out:
# Datasets:
# 	 space master dataset version 1
# 	 space shuttles dataset version 1
# 	 space reviews dataset version 1
# 	 space companies dataset version 1
# 	 diabetes file dataset version 1
# 	 diabetes dataset version 1

# %%
# %%writefile $experiment_folder/train_space.py
"""
    #Data Science Step
    #Generate a script that create/train a model of simple linear regression
"""
# Import libraries
from azureml.core import Run
import argparse
import pandas as pd
import numpy as np


import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', default="space_model", help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# Get the experiment run context
run = Run.get_context()

# load the diabetes data (passed as an input dataset)
print("Loading Data...")
space = run.input_datasets['space_master'].to_pandas_dataframe()

# Separate features and labels
X, y = space[['engines','passenger_capacity','crew','d_check_complete','moon_clearance_complete']].values, space['price'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3)

# Train Linear Regression model
print('Training a Linear Regression model')
model = LinearRegression().fit(X_train, y_train)

# calculate R2 Score
y_pred = model.predict(X_test)
score = r2_score(y_test, y_pred)
print('Regressor Model R2 Score:', score)
run.log('R2 Score', np.float(score))

# Save the trained model
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/model.pkl"
joblib.dump(value=model, filename=output_path)

run.complete()
# Out:
# Overwriting space_pipeline/train_space.py

# %%
# %%writefile $experiment_folder/register_space.py
"""
    #Data Science Step
    #Register the model
"""
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="space_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'space_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Overwriting space_pipeline/register_space.py

# %%
#Prepare Compute Enviornment and Cluster

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "aml-cluster"

# Verify that cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           max_nodes=4,
                                                           idle_seconds_before_scaledown=1800)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
#Configure Enviornment + Dependencies
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("space-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas'],
                                             pip_packages=['azureml-sdk'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment (just in case you want to use it again)
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'space-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %%
#Pipeline generation

from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Get the training dataset
space_ds = ws.datasets.get("space master dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

estimator = Estimator(source_directory=experiment_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='train_space.py')

# Step 1, run the estimator to train the model
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[space_ds.as_named_input('space_master')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)

# Step 2, run the model registration script
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_space.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
#Building the pipeline with the steps defined previously

from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'space-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step Train Model [1b1506cd][7e0ecade-2e2a-4d01-bfcb-5c9a4cfca0f3], (This step will run and generate new outputs)
# Created step Register Model [4156d2e7][9d1ec792-38e0-4650-b09a-8dc903da8dc3], (This step will run and generate new outputs)
# Submitted PipelineRun 1426257e-e951-435e-88f7-4b996f28ecf4
# Link to Azure Machine Learning studio: https://ml.azure.com/experiments/space-training-pipeline/runs/1426257e-e951-435e-88f7-4b996f28ecf4?wsid=/subscriptions/812800e3-0579-4b9a-b1a6-a53215573bf6/resourcegroups/ml-full-pipeline/workspaces/ml-fullpipe-practice
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 1426257e-e951-435e-88f7-4b996f28ecf4
# Link to Portal: https://ml.azure.com/experiments/space-training-pipeline/runs/1426257e-e951-435e-88f7-4b996f28ecf4?wsid=/subscriptions/812800e3-0579-4b9a-b1a6-a53215573bf6/resourcegroups/ml-full-pipeline/workspaces/ml-fullpipe-practice
# PipelineRun Status: Running
#
#
# StepRunId: 5c6acb72-ef46-41d0-b7a6-fc5043d24c1d
# Link to Portal: https://ml.azure.com/experiments/space-training-pipeline/runs/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d?wsid=/subscriptions/812800e3-0579-4b9a-b1a6-a53215573bf6/resourcegroups/ml-full-pipeline/workspaces/ml-fullpipe-practice
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ========================================================================================================================
# 2020-03-05T21:36:32Z Starting output-watcher...
# 2020-03-05T21:36:32Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_560f6eedad5148301b594ab99f81d58f
# Digest: sha256:c25dac037eefcb6b4fafb394929c10b21e4405c477716d0d8dc6e2d9fdd9a2c9
# Status: Image is up to date for mlfullpipepr4800736b.azurecr.io/azureml/azureml_560f6eedad5148301b594ab99f81d58f:latest
# d1d8246303275687451d9d0cb0b1963f32131eeeb5912d592bf868ece30c3979
# 2020/03/05 21:36:34 Version: 3.0.01154.0001 Branch: master Commit: fd92aa9d
# 2020/03/05 21:36:35 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/03/05 21:36:35 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
#
# Streaming azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ===============================================================================================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-05T21:36:44.936145
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 20b0b83f-b522-447c-98db-2a205a2bf686
# Starting the daemon thread to refresh tokens in background for process with pid = 96
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Acquired lockfile /tmp/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d-datastore.lock to downloading input data references
# Download or mount from datasets if requested.
# Job preparation is complete. Current time:2020-03-05T21:36:49.568524
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting the daemon thread to refresh tokens in background for process with pid = 155
# Entering Run History Context Manager.
# Preparing to call script [ train_space.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-fullpipe-practice/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/mounts/workspaceblobstore/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder']
# After variable expansion, calling script [ train_space.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-fullpipe-practice/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/mounts/workspaceblobstore/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder']
#
# Loading Data...
# /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/python3.6/site-packages/azureml/dataprep/api/dataflow.py:720: UserWarning: Please install pyarrow>=0.11.0 for improved performance of to_pandas_dataframe. You can ensure the correct version is installed by running: pip install azureml-dataprep[pandas].
#   warnings.warn('Please install pyarrow>=0.11.0 for improved performance of to_pandas_dataframe. '
# Training a Linear Regression model
# Regressor Model R2 Score: 0.4439100717765331
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.0018303394317626953 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 155
#
# Streaming azureml-logs/75_job_post-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ===============================================================================================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-03-05T21:37:32.200352
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 350
# Job release is complete. Current time:2020-03-05T21:37:34.397723
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '5c6acb72-ef46-41d0-b7a6-fc5043d24c1d', 'target': 'aml-cluster', 'status': 'Completed', 'startTimeUtc': '2020-03-05T21:36:35.706215Z', 'endTimeUtc': '2020-03-05T21:37:43.863252Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '20b0b83f-b522-447c-98db-2a205a2bf686', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.pipelinerunid': '1426257e-e951-435e-88f7-4b996f28ecf4', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_560f6eedad5148301b594ab99f81d58f', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'fe0ae660-8a2f-4cd0-83ec-b5e3565de97d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'space_master', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'train_space.py', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'space_master': {'dataLocation': {'dataset': {'id': 'fe0ae660-8a2f-4cd0-83ec-b5e3565de97d'}, 'dataPath': None}, 'createOutputDirectories': False, 'mechanism': 'Direct', 'environmentVariableName': 'space_master', 'pathOnCompute': None, 'overwrite': False}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment space-training-pipeline Environment', 'version': 'Autosave_2020-03-05T21:25:06Z_8fa82043', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'name': 'azureml_4d1bb950928e397f3e05e61cdeb42445'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt?sv=2019-02-02&sr=b&sig=Uo%2BxufjILhTiXPPnN0JNgpvc0mhRjshUIDgUZZIwQe4%3D&st=2020-03-05T21%3A27%3A56Z&se=2020-03-06T05%3A37%3A56Z&sp=r', 'azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt?sv=2019-02-02&sr=b&sig=g7BoDspmZ%2BaLwIB2ckzibhwzuGO4dgqvE3SX88Ft7w4%3D&st=2020-03-05T21%3A27%3A56Z&se=2020-03-06T05%3A37%3A56Z&sp ...
#
#
#
#
# StepRunId: 3bb59463-2306-4487-bfab-cab6ac068cb0
# Link to Portal: https://ml.azure.com/experiments/space-training-pipeline/runs/3bb59463-2306-4487-bfab-cab6ac068cb0?wsid=/subscriptions/812800e3-0579-4b9a-b1a6-a53215573bf6/resourcegroups/ml-full-pipeline/workspaces/ml-fullpipe-practice
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Queued
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ========================================================================================================================
# 2020-03-05T21:38:41Z Starting output-watcher...
# 2020-03-05T21:38:41Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_560f6eedad5148301b594ab99f81d58f
# Digest: sha256:c25dac037eefcb6b4fafb394929c10b21e4405c477716d0d8dc6e2d9fdd9a2c9
# Status: Image is up to date for mlfullpipepr4800736b.azurecr.io/azureml/azureml_560f6eedad5148301b594ab99f81d58f:latest
# 5496ca15925fa146826211229cee9c16d9b87a2364ad400a76f77dff60021a19
# 2020/03/05 21:38:43 Version: 3.0.01154.0001 Branch: master Commit: fd92aa9d
# 2020/03/05 21:38:44 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/03/05 21:38:44 sshd runtime has already been installed in the container
# ssh-keygen: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# ssh-keygen: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libcrypto.so.1.0.0: no version information available (required by ssh-keygen)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
#
# Streaming azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ===============================================================================================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-05T21:38:53.554890
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 20b0b83f-b522-447c-98db-2a205a2bf686
# Starting the daemon thread to refresh tokens in background for process with pid = 98
# Starting project file download.
# Finished project file download.
# Download from datastores if requested.
# Acquired lockfile /tmp/3bb59463-2306-4487-bfab-cab6ac068cb0-datastore.lock to downloading input data references
# Download or mount from datasets if requested.
# Job preparation is complete. Current time:2020-03-05T21:38:58.313597
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting the daemon thread to refresh tokens in background for process with pid = 157
# Entering Run History Context Manager.
# Preparing to call script [ register_space.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-fullpipe-practice/azureml/3bb59463-2306-4487-bfab-cab6ac068cb0/mounts/workspaceblobstore/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder']
# After variable expansion, calling script [ register_space.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-fullpipe-practice/azureml/3bb59463-2306-4487-bfab-cab6ac068cb0/mounts/workspaceblobstore/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder']
#
# Loading model from /mnt/batch/tasks/shared/LS_root/jobs/ml-fullpipe-practice/azureml/3bb59463-2306-4487-bfab-cab6ac068cb0/mounts/workspaceblobstore/azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder
# Registering model space_model
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.0015354156494140625 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 157
#
# Streaming azureml-logs/75_job_post-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt
# ===============================================================================================================
# bash: /azureml-envs/azureml_4d1bb950928e397f3e05e61cdeb42445/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-03-05T21:39:15.447940
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 190
# Job release is complete. Current time:2020-03-05T21:39:18.479060
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '3bb59463-2306-4487-bfab-cab6ac068cb0', 'target': 'aml-cluster', 'status': 'Completed', 'startTimeUtc': '2020-03-05T21:38:40.426155Z', 'endTimeUtc': '2020-03-05T21:39:33.593768Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '20b0b83f-b522-447c-98db-2a205a2bf686', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.pipelinerunid': '1426257e-e951-435e-88f7-4b996f28ecf4', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_560f6eedad5148301b594ab99f81d58f', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_space.py', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'aml-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/5c6acb72-ef46-41d0-b7a6-fc5043d24c1d/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment space-training-pipeline Environment', 'version': 'Autosave_2020-03-05T21:25:06Z_8fa82043', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk']}, 'scikit-learn', 'pandas'], 'name': 'azureml_4d1bb950928e397f3e05e61cdeb42445'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.3bb59463-2306-4487-bfab-cab6ac068cb0/azureml-logs/55_azureml-execution-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt?sv=2019-02-02&sr=b&sig=fDiUBZVsE5HtJ%2Fnvu35iX3XtBON16jZN7L8zSMlyHIQ%3D&st=2020-03-05T21%3A29%3A45Z&se=2020-03-06T05%3A39%3A45Z&sp=r', 'azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.3bb59463-2306-4487-bfab-cab6ac068cb0/azureml-logs/65_job_prep-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff24d58dc8762dd588a3_d.txt?sv=2019-02-02&sr=b&sig=Ivgz%2BjBnRUX2gRt3k6lF5mg1Q9eRrp1SdhhcbdN3w0c%3D&st=2020-03-05T21%3A29%3A45Z&se=2020-03-06T05%3A39%3A45Z&sp=r', 'azureml-logs/70_driver_log.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.3bb59463-2306-4487-bfab-cab6ac068cb0/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=Sorqa7VUKbiCVeyHM6GG%2BgVlGxOY3mzpmuW0X%2B%2Fg4nE%3D&st=2020-03-05T21%3A29%3A46Z&se=2020-03-06T05%3A39%3A46Z&sp=r', 'azureml-logs/75_job_post-tvmps_d5efd74c435bd3393ef162fb499b62454610c93c31bcff ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '1426257e-e951-435e-88f7-4b996f28ecf4', 'status': 'Completed', 'startTimeUtc': '2020-03-05T21:35:46.133284Z', 'endTimeUtc': '2020-03-05T21:39:42.734181Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.1426257e-e951-435e-88f7-4b996f28ecf4/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=lN94EHl1SFWXxn3SntT%2BSdlZCtTv7l7tPsXaj1wCrD8%3D&st=2020-03-05T21%3A29%3A47Z&se=2020-03-06T05%3A39%3A47Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.1426257e-e951-435e-88f7-4b996f28ecf4/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=pIJAk76vr6QH2eDIsdhAzE6Ejd%2FuJW5mKRiCIsJh2kc%3D&st=2020-03-05T21%3A29%3A47Z&se=2020-03-06T05%3A39%3A47Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlfullpipeprac7400718063.blob.core.windows.net/azureml/ExperimentRun/dcid.1426257e-e951-435e-88f7-4b996f28ecf4/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=H22oec5NG5auGZOc9v0AaCf%2Fva7apDype2UBreUbJLI%3D&st=2020-03-05T21%3A29%3A47Z&se=2020-03-06T05%3A39%3A47Z&sp=r'}}
# 'Finished'

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# space_model version: 1
# 	 Training context : Pipeline
#
#
# diabetes_model version: 4
# 	 Training context : Pipeline
#
#
# diabetes_model version: 3
# 	 Training context : Pipeline
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 1
# 	 Training context : Estimator
# 	 AUC : 0.8483203144435048
# 	 Accuracy : 0.774

# %%
published_pipeline = pipeline.publish(name="Space_Training_Pipeline",
                                      description="Trains space model",
                                      version="1.0")
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus.aether.ms/api/v1.0/subscriptions/812800e3-0579-4b9a-b1a6-a53215573bf6/resourceGroups/ml-full-pipeline/providers/Microsoft.MachineLearningServices/workspaces/ml-fullpipe-practice/PipelineRuns/PipelineSubmit/836fb06e-60ef-4e72-86a7-6cbdfeb31d97

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %%
import requests
experiment_name = 'Run-diabetes-pipeline'

response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# 'b0e91367-171d-4c13-825d-25e27f55b551'

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
